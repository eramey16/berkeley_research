# %% [markdown]
# # Let's Explore Keck's Telemetry!
# ### This notebook will walk you through how to open one of the telemetry files in python, which are binary .sav files written in IDL, and access the structured arrays within.

# %% [markdown]
# #### Preamble

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import readsav  # This allows you to open the IDL binaries in python
import pandas as pd
from astropy.table import Table
import glob
import time

# %% [markdown]
# #### Open the file

# %%
file = '/g/lu/data/keck_telemetry/20170718/sdata901/nirc15/2017jul18/n0101_LGS_trs.sav'
data = readsav(file)

# %% [markdown]
# #### The .keys() method allows you to see the attributes of data.

# %%
data.keys()
# Out:
# dict_keys(['a', 'b', 'uid', 'cid', 'nrec', 'rx', 'cent_origin', 'dm_origin', 'dtt_offset', 'tstamp_num', 'tstamp_str_start', 'cent_g', 'dm_servo', 'dt_servo', 'apd_imat', 'apd_sky_back', 'apd_threshold', 'header'])

# %% [markdown]
# #### You can access each attribute normally.  Some just contain a value...

# %%
data.tstamp_str_start
# Out:
# b'2017-07-18T09:34:05.631'

# %% [markdown]
# #### ...most attributes contain either arrays or structured arrays

# %%
data.tstamp_num
# Out:
# array([ 6.61927238e-02,  1.32079870e-01,  4.26808111e-02,  1.65010765e-01,
#        -8.21094960e-03, -9.18231085e-02,  3.68305817e-02, -1.35082245e-01,
#        -5.51547557e-02,  9.91059989e-02, -2.20762566e-04,  2.62678061e-02,
#         4.39986438e-02, -9.54456329e-02,  1.53060287e-01, -9.62878391e-02,
#         2.14432105e-02,  5.75800426e-03, -1.42525155e-02, -8.80937837e-03,
#         5.75197637e-02, -8.07220563e-02,  8.35405849e-03, -5.21110669e-02,
#        -2.10131519e-02,  5.93136549e-02, -2.87907831e-02, -2.25639921e-02,
#        -1.78042054e-03, -6.45869300e-02,  3.79456021e-02, -6.92330487e-03,
#         5.73126972e-02, -7.28314742e-03,  2.12336648e-02, -6.37171715e-02,
#        -2.22410075e-02, -4.51806560e-02, -4.76709194e-02, -3.23732495e-02,
#        -5.69021702e-03, -8.48778859e-02,  2.31571179e-02,  3.59686911e-02,
#         9.19239037e-03, -5.57271838e-02, -3.75871956e-02,  3.79881375e-02,
#         8.43257606e-02, -4.69289906e-02,  2.66744029e-02, -1.98171586e-02,
#         1.93217285e-02, -7.61868060e-02,  5.86426109e-02, -4.53106575e-02,
#        -1.34811876e-02, -6.14371188e-02,  5.44682937e-03, -5.30168265e-02,
#         1.05011955e-01, -3.90291996e-02,  6.46918267e-02, -9.41459015e-02,
#         8.47927034e-02,  9.25292447e-02, -2.49426775e-02,  5.95424138e-02,
#        -5.04408590e-02, -1.13338046e-01,  1.08841904e-01, -9.86839905e-02,
#         6.05235696e-02, -8.62003863e-03, -4.95556556e-02, -4.21210229e-02,
#        -5.06952405e-04, -7.22209066e-02, -3.04946098e-02, -4.72219810e-02,
#         5.89993224e-03, -1.67964566e-02, -3.98545228e-02,  8.83508623e-02,
#         4.55658287e-02, -7.82711282e-02,  2.28010342e-02, -3.69775183e-02,
#         3.72478068e-02,  1.18853115e-02, -1.28276777e-02,  8.95389020e-02,
#        -9.55233444e-03, -1.10771194e-01,  3.35467868e-02,  3.53876092e-02,
#        -2.03302559e-02, -2.07670592e-02, -3.70918959e-02, -4.53405045e-02,
#        -8.42801109e-02, -4.72187437e-02, -3.51498052e-02,  1.95351895e-04,
#        -2.71770265e-02, -4.92612086e-02, -2.04055309e-02,  2.86222752e-02,
#        -1.01199515e-01, -1.51552781e-01,  4.85221334e-02,  3.92433479e-02,
#         1.39881559e-02, -4.94082123e-02, -2.27015503e-02,  9.51622725e-02,
#        -2.42614374e-02, -2.51485053e-02, -3.14876437e-02,  3.81334871e-02,
#         5.70343062e-02,  2.15160791e-02,  4.33695167e-02, -7.69820958e-02,
#        -3.95455491e-03,  3.54796574e-02, -3.72688775e-03,  8.16949829e-02,
#         1.31091969e-02,  9.66263115e-02, -9.94573683e-02,  3.94571535e-02,
#         4.16048057e-02,  1.23943143e-01, -7.82379508e-02,  2.15036310e-02,
#         8.45989138e-02,  9.15120617e-02,  4.75440873e-03,  7.92754591e-02,
#        -1.32415801e-01,  1.03363052e-01, -3.43516655e-03,  2.43947487e-02,
#         9.79088992e-02, -8.33647400e-02,  9.23464894e-02,  2.11229920e-02,
#         1.33980270e-02,  3.89686748e-02, -1.43748149e-01,  5.82409725e-02,
#        -1.36055097e-01, -5.12488037e-02, -5.61893545e-02,  1.09548472e-01,
#         1.96179152e-02, -1.32973269e-02,  1.21449143e-01,  2.82361228e-02,
#        -2.97741741e-02,  5.01093231e-02,  2.05515567e-02,  2.96453070e-02,
#        -4.24619354e-02,  1.49914101e-01, -2.70795785e-02,  9.93279740e-02],
#       dtype=float32)

# %% [markdown]
# #### AO information is contained within the data.a structured array.  Access the array header keywords with data.a.dtype.fields:

# %%
data.a.dtype.fields
# Out:
# mappingproxy({'CONF_ID': (dtype('O'), 0, 'conf_id'),
#               'DMCOMMAND': (dtype('O'), 40, 'dmcommand'),
#               'DMCOMMANDSCLIPPED': (dtype('O'), 48, 'dmcommandsclipped'),
#               'OFFSETCENTROID': (dtype('O'), 24, 'offsetcentroid'),
#               'RESIDUALRMS': (dtype('O'), 56, 'residualrms'),
#               'RESIDUALWAVEFRONT': (dtype('O'), 32, 'residualwavefront'),
#               'SUBAPINTENSITY': (dtype('O'), 16, 'subapintensity'),
#               'TIMESTAMP': (dtype('O'), 8, 'timestamp'),
#               'TTCOMMANDS': (dtype('O'), 64, 'ttcommands'),
#               'TTCOMMANDSCLIPPED': (dtype('O'), 80, 'ttcommandsclipped'),
#               'TTSTRAINGAUGE': (dtype('O'), 72, 'ttstraingauge'),
#               'conf_id': (dtype('O'), 0, 'conf_id'),
#               'dmcommand': (dtype('O'), 40, 'dmcommand'),
#               'dmcommandsclipped': (dtype('O'), 48, 'dmcommandsclipped'),
#               'offsetcentroid': (dtype('O'), 24, 'offsetcentroid'),
#               'residualrms': (dtype('O'), 56, 'residualrms'),
#               'residualwavefront': (dtype('O'), 32, 'residualwavefront'),
#               'subapintensity': (dtype('O'), 16, 'subapintensity'),
#               'timestamp': (dtype('O'), 8, 'timestamp'),
#               'ttcommands': (dtype('O'), 64, 'ttcommands'),
#               'ttcommandsclipped': (dtype('O'), 80, 'ttcommandsclipped'),
#               'ttstraingauge': (dtype('O'), 72, 'ttstraingauge')})

# %% [markdown]
# #### data.b is also structured, and contains

# %%
data.b.dtype.fields
# Out:
# mappingproxy({'APDCOUNTS': (dtype('O'), 16, 'apdcounts'),
#               'CONF_ID': (dtype('O'), 0, 'conf_id'),
#               'DTTCENTROIDS': (dtype('O'), 24, 'dttcentroids'),
#               'DTTCOMMANDS': (dtype('O'), 32, 'dttcommands'),
#               'DTTCOMMANDSCLIPPED': (dtype('O'), 48, 'dttcommandsclipped'),
#               'DTTSTRAINGAUGE': (dtype('O'), 40, 'dttstraingauge'),
#               'TIMESTAMP': (dtype('O'), 8, 'timestamp'),
#               'apdcounts': (dtype('O'), 16, 'apdcounts'),
#               'conf_id': (dtype('O'), 0, 'conf_id'),
#               'dttcentroids': (dtype('O'), 24, 'dttcentroids'),
#               'dttcommands': (dtype('O'), 32, 'dttcommands'),
#               'dttcommandsclipped': (dtype('O'), 48, 'dttcommandsclipped'),
#               'dttstraingauge': (dtype('O'), 40, 'dttstraingauge'),
#               'timestamp': (dtype('O'), 8, 'timestamp')})

# %% [markdown]
# #### To check the clock frequency, we can look at two adjacent timestamps:

# %%
dt = (data.a.timestamp[0][2] - data.a.timestamp[0][1]) * 1e-7
freq = 1 / dt
print(freq)
# Out:
# 999.6001599360255

# %%
exp_dt = 105.15 - 31.676
exp_dt
# Out:
# 73.474

# %%
1 / (dt*1e-7)
# Out:
# 999.7000899730082

# %%
data.header
# Out:
# array([b'SIMPLE  =                    T / Tape is in Fits format                         ',
#        b'BITPIX  =                   32 / Bits per pixel                                 ',
#        b'NAXIS   =                    2 / Number of axes                                 ',
#        b'NAXIS1  =                 1024 / Number of pixels in axis 1                     ',
#        b'NAXIS2  =                 1024 / Number of pixels in axis 2                     ',
#        b'BSCALE  =              1.00000 / Scaling factor                                 ',
#        b'BZERO   =              0.00000 / Scaling zero-point                             ',
#        b"OUTDIR  = '/sdata904/nirc7/2017aug08/            ' / Original directory         ",
#        b"ROOTNAME= 'n                 ' / File prefix                                    ",
#        b'FRAMENO =                   87 / Frame number                                   ',
#        b"FILENAME= 'n0087.fits        ' / Original File name                             ",
#        b"TELESCOP= 'Keck II           ' / Telescope                                      ",
#        b"OBSERVER= 'J.Lu,Siyao        ' / Observer                                       ",
#        b"OBJECT  = 'GalCenterSagA     ' / Object name                                    ",
#        b"COMMENT = 'LGSAO checkout    ' / Comment                                        ",
#        b'ITIME   =                2.800 / Integration time per coadd                     ',
#        b"EXPSTART= '06:08:31.676      ' / Exposure start time (UT)                       ",
#        b"EXPSTOP = '06:09:14.150      ' / Exposure stop time (UT)                        ",
#        b'COADDS  =                   10 / Number of coadds                               ',
#        b'SAMPMODE=                    3 / 1=Single; 2=CDS; 3=MCDS                        ',
#        b'DETBIAS =                  450 / Detector bias setting (0-4096)                 ',
#        b'MULTISAM=                    8 / Number of multiple reads                       ',
#        b'Q1OFFSET=                 3172 / Aladdin Quadrant 1 preamp offset               ',
#        b'Q2OFFSET=                 3183 / Aladdin Quadrant 2 preamp offset               ',
#        b'Q3OFFSET=                 3180 / Aladdin Quadrant 3 preamp offset               ',
#        b'Q4OFFSET=                 3183 / Aladdin Quadrant 4 preamp offset               ',
#        b'GAIN    =                    4 / Detector Gain Setting                          ',
#        b'PREOFF  =                  400 / Preamp Offset Voltage                          ',
#        b'SAMPRATE=                  200 / Pixel rate in kps                              ',
#        b"IMAGETYP= 'data              ' /                                                ",
#        b'SLITMM  =             -0.18029 /                                                ',
#        b"SLITNAME= 'none              ' /                                                ",
#        b'SLITTILT=              0.00000 /                                                ',
#        b'ARGONPWR=                    0 /                                                ',
#        b'KRYPTPWR=                    0 /                                                ',
#        b'LAMPPWR =                    0 /                                                ',
#        b'NEONPWR =                    0 /                                                ',
#        b'XENONPWR=                    0 /                                                ',
#        b"CAMDIST =            260.60599 / camera slider's distance from                  ",
#        b"CAMNAME = 'narrow            ' / camera slider's named position                 ",
#        b"CAMRAW  =               260606 / camera slider's encoder positi                 ",
#        b'CENWAVE =              2.12450 / central wavelength of passband                 ',
#        b'MINWAVE =              1.94900 / minimum wavelength of passband                 ',
#        b'MAXWAVE =              2.30000 / maximum wavelength of passband                 ',
#        b'EFFWAVE =              2.12450 / effective wavelength of passba                 ',
#        b"FWIANGL =            129.20041 / inner filter wheel's angular p                 ",
#        b"FWINAME = 'Kp                ' / inner filter wheel's named pos                 ",
#        b'FWINUM  =                    7 /                                                ',
#        b"FWIRAW  =               135889 / inner filter wheel's encoder p                 ",
#        b"FWOANGL =            329.19842 / outer filter wheel's angular p                 ",
#        b"FWONAME = 'clear             ' / outer filter wheel's named pos                 ",
#        b'FWONUM  =                   17 /                                                ',
#        b"FWORAW  =               191444 / outer filter wheel's encoder p                 ",
#        b"FILTER  = 'Kp + clear        ' / composite filter name (both wh                 ",
#        b"GRSDIST =            132.04849 / grism slider's distance from h                 ",
#        b"GRSNAME = 'clear             ' / grism slider's named position                  ",
#        b"GRSRAW  =               264097 / grism slider's encoder positio                 ",
#        b"PMSANGL =            296.69037 / pupil wheel's angular position                 ",
#        b"PMSNAME = 'largehex          ' / pupil wheel's named position                   ",
#        b"PMSRAW  =               182414 / pupil wheel's encoder position                 ",
#        b"PMRANGL =            164.29047 / pupil drive's angular position                 ",
#        b"PSIDIST =              4.51793 / Inner preslit's distance from                  ",
#        b"PSINAME = 'mfov_center       ' / Inner preslit's named position                 ",
#        b"PSIRAW  =                34517 / Inner preslit's encoder positi                 ",
#        b"PSODIST =              4.46963 / Outer preslit's distance from                  ",
#        b"PSONAME = 'nfov_center       ' / Outer preslit's named position                 ",
#        b"PSORAW  =                34148 / Outer preslit's encoder positi                 ",
#        b"SHRDIST =              0.03600 / Shutter's distance from home (                 ",
#        b"SHRNAME = 'open              ' / Shutter's named position                       ",
#        b"SHRRAW  =                   72 / shutter's encoder position                     ",
#        b"SLSDIST =            254.36150 / slit slide's distance from hom                 ",
#        b"SLSNAME = 'clear             ' / slit slide's named position                    ",
#        b"SLSRAW  =               508723 / slit slide's encoder position                  ",
#        b"SLMDIST =            179.93750 / slit mask's distance from home                 ",
#        b"SLMNAME = 'narrow_clear      ' / slit mask's named position                     ",
#        b"SLMRAW  =               359875 / slit mask's encoder position                   ",
#        b'AODELAY =                    0 / Delay after AO locks                           ',
#        b"UTC     = '06:08:31.46       ' / coordinated universal time (h)                 ",
#        b'AIRMASS =              1.56658 / air mass (1.57)                                ',
#        b"AXESTAT = 'tracking          ' / axes control status                            ",
#        b'AZ      =            165.07650 / telescope azimuth (165.08 deg)                 ',
#        b'CALOCAL =             -0.01023 / collimation azimuth local (-36                 ',
#        b'CELOCAL =             -0.01111 / collimation elevation local (-                 ',
#        b"CURRINST= 'NIRC2             ' / current instrument                             ",
#        b"DATE-OBS= '2017-08-08        ' / universal date of observation                  ",
#        b"DCSSTAT = 'standby           ' / drive and control status                       ",
#        b'DEC     =            -29.00823 / telescope declination (-29:00:                 ',
#        b'DECOFF  =              0.00000 / declination offset (0.0 arcsec                 ',
#        b'DOMEPOSN=            164.98219 / dome azimuth (164.98 deg)                      ',
#        b"DOMESTAT= 'tracking          ' / dome status                                    ",
#        b'EL      =             39.60472 / telescope elevation (39.60 deg                 ',
#        b'EQUINOX =           2000.00000 / telescope equinox (2000.0)                     ',
#        b"FOCALSTN= 'lnas (left nasmyth)' / focal station                                 ",
#        b"GUIDWAVE= '0.732             ' / guidestar wavelength (microns)                 ",
#        b'HA      =            -13.09627 / telescope hour angle (+23:07:3                 ',
#        b'INSTANGL=              0.70000 / porg to instrument angle (0.7                  ',
#        b"INSTFLIP= 'no                ' / porg to instrument y flip                      ",
#        b"LST     = '16:54:24.38       ' / local apparent sidereal time (                 ",
#        b'MJD-OBS =          57973.25592 / modified julian date of observ                 ',
#        b'PARANG  =            -15.93570 / parallactic angle astrometric                  ',
#        b'PARANTEL=            -15.95496 / parallactic angle telescope (-                 ',
#        b'DRA     =              0.00000 / diff ra rate (0.000000 seconds                 ',
#        b'DDEC    =              0.00000 / diff decl rate (0.0000000 arcs                 ',
#        b"DTRACK  = 'disabled          ' / differential tracking enabled                  ",
#        b'RA      =            266.41662 / telescope right ascension (17:                 ',
#        b'RAOFF   =             -0.00000 / right ascension offset (-0.0 a                 ',
#        b'ROTCALAN=              0.00000 / rotator calibration angle (0.0                 ',
#        b"ROTMODE = 'position angle    ' / rotator tracking mode                          ",
#        b'ROTPDEST=             56.25957 / rotator physical destination (                 ',
#        b'ROTPPOSN=             56.27014 / rotator physical position (56.                 ',
#        b'ROTDEST =              0.70000 / rotator user destination (0.70                 ',
#        b'ROTPOSN =              0.70000 / rotator user position (0.70 de                 ',
#        b'ROTREFAN=              0.00000 / rotator reference angle (0.00                  ',
#        b'SECFOCUS=              0.00033 / secondary mirror focus raw (0.                 ',
#        b"SECTHETX= '-64.7             ' / secondary mirror thetax (arcse                 ",
#        b"SECTHETY= '-239.0            ' / secondary mirror thetay (arcse                 ",
#        b"TARGNAME= 'tt000             ' / target name                                    ",
#        b"TARGWAVE= '2.124             ' / target wavelength (microns)                    ",
#        b"TELESCOP= 'Keck II           ' / telescope name                                 ",
#        b'TELFOCUS=              0.00097 / telescope focus compensated (0                 ',
#        b'TUBETEMP=              3.43760 / tube temperature (3.44 degC)                   ',
#        b"FLIMAGIN= 'off               ' / flat lamp control 1                            ",
#        b"FLSPECTR= 'off               ' / flat lamp control 2                            ",
#        b"AOOPSMOD= '2                 ' / AO General Ops Mode FITS                       ",
#        b"AODMSTAT= 'closed            ' / AO deformable mirror loop stat                 ",
#        b"AODTSTAT= 'closed            ' / AO downlink tip/tilt loop stat                 ",
#        b"AOTTMODE= 'closed            ' / AO tip/tilt offloading mode                    ",
#        b"AOAOAMED= '893               ' / AO WFC AOA camera median light                 ",
#        b"AOLBFWHM= '1.009680          ' / AO LBWFS avg fwhm                              ",
#        b"WSFRRT  = '440               ' / Frame rate for WFS cam (Hz)                    ",
#        b"DMGAIN  = '0.400             ' / Set DM loop gain                               ",
#        b"DMMRFN  = '8Aug0020.mr       ' / Name of DM reconstructor file                  ",
#        b"DTGAIN  = '0.150             ' / Set TT loop gain                               ",
#        b"AOWFC0  = '-1.262000         ' / AO WFS focus stage FSM coeffic                 ",
#        b"AOFCNGFO= '-0.001119         ' / AO FC NGS Focus Calc Value (m)                 ",
#        b"AOFCLGFO= '0.164035          ' / AO FC LGS pregain focus calc v                 ",
#        b"AOFCLBFO= '0.001410          ' / AO FC LBWFS pregain focus calc                 ",
#        b"AOFCNGCT= 'ON                ' / AO FC NGS control                              ",
#        b"AOFCLGCT= 'ON                ' / AO FC LGS control                              ",
#        b"AOFCLBCT= 'ON                ' / AO FC LBWFS control                            ",
#        b"AOFCSALT= '87537             ' / AO FC sodium alt preset (m)                    ",
#        b"AOFOMODE= 'closed            ' / AO focus offloading mode                       ",
#        b"AOTSDAR = 'false             ' / AO TSS_USE_DAR?                                ",
#        b"AODRDTEN= '0.0               ' / AO DAR DTT CTRLOFF ENABLE                      ",
#        b"AODRENA = '1.0               ' / AO DAR_ENABLE/DISABLE                          ",
#        b"AOTSZ   = '39.041            ' / AO tip/tilt sensor stage Z pos                 ",
#        b"AOTSX   = '-6.736            ' / AO tip/tilt sensor stage X pos                 ",
#        b"AOTSY   = '22.278            ' / AO tip/tilt sensor stage Y pos                 ",
#        b"OBTSNAME= 'noName            ' / Named position control for TSS                 ",
#        b"OBTSX   = '-20.49            ' / User value of TSS x axis (mm)                  ",
#        b"OBTSY   = '37.01             ' / User value of TSS y axis (mm)                  ",
#        b"OBTSZ   = '39.04             ' / User value of TSS z axis (mm)                  ",
#        b"AOLPMOVE= 'false             ' / AO LSP MOVE ENABLE                             ",
#        b"LGRMSWF = '272.7             ' / LGSAO RMS WF Residual                          ",
#        b"LSAMPPWR= '22.112240         ' / LASER Unit1 Power (watts)                      ",
#        b"LSPROP  = 'yes               ' / LASER PROPAGATING LEGACY SIDEL                 ",
#        b"AOFMX   = '-0.05             ' / AO field steering mirrors X po                 ",
#        b"AOFMY   = '8.82              ' / AO field steering mirrors Y po                 ",
#        b"OBFMXIM = '8.820             ' / Image plane x motion for FSM (                 ",
#        b"OBFMYIM = '-0.050            ' / Image plane y motion for FSM (                 ",
#        b"OBFMXPU = '0.00              ' / Pupil plane x motion for FSM (                 ",
#        b"OBFMYPU = '0.00              ' / Pupil plane y motion for FSM (                 ",
#        b"OBFMDREN= '0.000000          ' / FSM Coordinated move use dar o                 ",
#        b"OBFSNAME= '2.4               ' / Named position control for FSS                 ",
#        b"OBIMNAME= 'out               ' / Named position control for ISM                 ",
#        b"OBLBNAME= 'noName            ' / Named position control for LBS                 ",
#        b"OBAMNAME= 'open              ' / Named position control for AFM                 ",
#        b"OBRT    = '28.1316           ' / User value of ROT (deg)                        ",
#        b"OBSDNAME= 'sodiumDichroic    ' / Named position control for SOD                 ",
#        b"OBSFX   = '-118.99           ' / User value of SFP x axis (mm)                  ",
#        b"OBSFY   = '-0.00             ' / User value of SFP y axis (mm)                  ",
#        b"OBSFZ   = '-0.00             ' / User value of SFP z axis (mm)                  ",
#        b"OBSI    = '-1.50             ' / User value of SFD (mm)                         ",
#        b"OBSFNAME= 'telescope         ' / Named position control for SFP                 ",
#        b"OBSNNAME= 'block             ' / Named position control for SND                 ",
#        b"OBWCNAME= '2.4               ' / Named position control for WCS                 ",
#        b"OBWFSTST= 'TRACK             ' / State of FCS as string                         ",
#        b"OBWLNAME= '2.4               ' / Named position control for WLS                 ",
#        b"OBWPNAME= 'ngs               ' / Named position control for WPS                 ",
#        b"OBWNNAME= 'open              ' / Named position control for WND                 ",
#        b"OBSWSTA = 'off               ' / White light power status                       ",
#        b"OBSWNAME= 'open              ' / Named position control for SFW                 ",
#        b"OBWF    = '164.323           ' / User value of FCS (mm)                         ",
#        b"WSSMPRG = '2                 ' / WFS_SciMeas program (0)                        ",
#        b"WSSMREP = '2508              ' / WFS SciMeas repetitions (incre                 ",
#        b"WSSMGN  = '0                 ' / WFS gain (0)                                   ",
#        b"WSCNORFN= 'lgs0046.cog       ' / Name of origin vec file                        ",
#        b"WCDTSTAT= 'CLOSED_APD        ' / Status of down tt loop                         ",
#        b"WCDMSTAT= 'CLOSED            ' / Status of DM loop                              ",
#        b"WCUTSTAT= 'CLOSED            ' / Status of utt loop                             ",
#        b"DTCLP   = 'CLOSE             ' / OPEN/CLOSE TT CLMP ctrl loop                   ",
#        b"UTCLP   = 'CLOSE             ' / OPEN/CLOSE TT CLMP ctrl loop                   ",
#        b"UTGAIN  = '0.100             ' / Set TT loop gain                               ",
#        b"STAPDQMN= '43308.500         ' / STRAP Quad Mean APD counts (co                 ",
#        b"STINTTIM= '8                 ' / STRAP Set int time (milli-sec)                 ",
#        b'END                                                                             '],
#       dtype=object)

# %%
data.a.residualwavefront[0].shape
# Out:
# (18707, 352)

# %%
data.b.dttcommands[0].shape
# Out:
# (5314, 2)

# %%
plt.plot(data.a.residualwavefront[0][:,0])
plt.show()

# %%
plt.figure(figsize = (12,8))
plt.plot(data.a.residualrms[0][0][1000:1100])
plt.show()

# %%
data.a.residualrms[0][0].shape
# Out:
# (18707,)

# %%
rms_mean = data.a.residualrms[0][0].mean()

# %%
df_rms.columns
# Out:
# Index(['file', 'strehl', 'rms_err', 'fwhm', 'mjd', 'epoch', 'airmass', 'itime',
#        'coadds', 'band', 'az', 'dmgain', 'dtgain', 'wsfrrt', 'aolbfwhm',
#        'lsamppwr', 'lgrmswf', 'xref', 'yref', 'xstrehl', 'ystrehl', 'MASS',
#        'MASS_mjd', 'MASS_delta_t', 'DIMM', 'DIMM_mjd', 'DIMM_delta_t',
#        'MASSPRO_half', 'MASSPRO_1', 'MASSPRO_2', 'MASSPRO_4', 'MASSPRO_8',
#        'MASSPRO_16', 'MASSPRO', 'MASSPRO_mjd', 'MASSPRO_delta_t',
#        'wind_speed[kts]', 'wind_speed', 'wind_direction', 'temperature',
#        'relative_humidity', 'pressure[mb]', 'pressure', 'cfht_mjd',
#        'cfht_delta_t', 'telemetry_file', 'residual_rms'],
#       dtype='object')

# %%
print(df_rms.rms_err[0], rms_mean)
# Out:
# 491.7 186.6835

# %%
data.a.DMCOMMAND[0].shape
# Out:
# (18707, 349)

# %%
plt.figure(figsize = (12,8))
plt.plot(data.a.dmcommand[0][0])
plt.show()

# %%
plt.figure(figsize = (8,8))
plt.plot(data.a.ttcommands[0][:,0],data.a.ttcommands[0][:,1])
plt.show()

# %%
data.a.residualwavefront[0][:,350].shape
# Out:
# (18707,)

# %%
data.a.ttcommands[0].shape
# Out:
# (18707, 2)

# %%
ngs = glob.glob()

# %%
df_rms[:10]
# Out:
#          file  strehl  rms_err    fwhm          mjd      epoch  airmass  \
# 0  c0087.fits   0.121    491.7  104.67  57973.25592  17auglgs1  1.56658
# 1  c0088.fits   0.150    465.4   93.87  57973.25651  17auglgs1  1.56489
# 2  c0089.fits   0.169    451.0   85.63  57973.25709  17auglgs1  1.56328
# 3  c0090.fits   0.127    485.7  101.55  57973.25779  17auglgs1  1.56134
# 4  c0091.fits   0.138    475.7   95.98  57973.25838  17auglgs1  1.55976
# 5  c0092.fits   0.124    488.6  100.16  57973.25898  17auglgs1  1.55820
# 6  c0093.fits   0.106    506.5  109.37  57973.25956  17auglgs1  1.55676
# 7  c0094.fits   0.081    535.9  134.24  57973.26015  17auglgs1  1.55525
# 8  c0097.fits   0.054    577.7  174.25  57973.26486  17auglgs1  1.54437
# 9  c0098.fits   0.061    566.2  163.00  57973.26590  17auglgs1  1.54228
#
#    itime  coadds band      ...       wind_speed  wind_direction  temperature  \
# 0    2.8    10.0   Kp      ...         3.601111            93.0         2.64
# 1    2.8    10.0   Kp      ...         3.601111            93.0         2.64
# 2    2.8    10.0   Kp      ...         3.601111            95.0         2.63
# 3    2.8    10.0   Kp      ...         4.115556            83.0         2.63
# 4    2.8    10.0   Kp      ...         3.601111            91.0         2.62
# 5    2.8    10.0   Kp      ...         4.115556            86.0         2.63
# 6    2.8    10.0   Kp      ...         4.115556            88.0         2.63
# 7    2.8    10.0   Kp      ...         4.115556            92.0         2.64
# 8    2.8    10.0   Kp      ...         3.601111            89.0         2.67
# 9    2.8    10.0   Kp      ...         4.630000            93.0         2.66
#
#    relative_humidity  pressure[mb]  pressure      cfht_mjd  cfht_delta_t  \
# 0               24.0         620.5    0.6205  57973.256250     -0.000330
# 1               24.0         620.5    0.6205  57973.256250      0.000260
# 2               24.0         620.5    0.6205  57973.256944      0.000146
# 3               24.0         620.5    0.6205  57973.257639      0.000151
# 4               23.0         620.5    0.6205  57973.258333      0.000047
# 5               23.0         620.5    0.6205  57973.259028     -0.000048
# 6               23.0         620.5    0.6205  57973.259722     -0.000162
# 7               24.0         620.5    0.6205  57973.260417     -0.000267
# 8               24.0         620.5    0.6205  57973.264583      0.000277
# 9               23.0         620.5    0.6205  57973.265972     -0.000072
#
#                                       telemetry_file  residual_rms
# 0  /u/steverobinson/data/keck_telemetry/20170808/...    189.216705
# 1  /u/steverobinson/data/keck_telemetry/20170808/...    228.859436
# 2  /u/steverobinson/data/keck_telemetry/20170808/...    152.201874
# 3  /u/steverobinson/data/keck_telemetry/20170808/...    200.610062
# 4  /u/steverobinson/data/keck_telemetry/20170808/...    164.941544
# 5  /u/steverobinson/data/keck_telemetry/20170808/...    114.302696
# 6  /u/steverobinson/data/keck_telemetry/20170808/...    140.143188
# 7  /u/steverobinson/data/keck_telemetry/20170808/...    104.838692
# 8  /u/steverobinson/data/keck_telemetry/20170808/...    169.382095
# 9  /u/steverobinson/data/keck_telemetry/20170808/...    230.655441
#
# [10 rows x 47 columns]

# %%
df_rms.shape[0]
# Out:
# 956

# %%
# rms = []
# rms_err = []
# tt_x = []
# tt_x_err = []
# tt_y = []
# tt_y_err = []
# defocus = []
# defocus_err = []
# for i, row in df_rms[:10].iterrows():
start = time.time()
for i in range(100,df_rms.shape[0]):
    tele_file = df_rms.telemetry_file[i].replace('/u/steverobinson', '/g/lu')
    data = readsav(tele_file)
    rms.append(data.a.residualrms[0][0].mean())
    rms_err.append(data.a.residualrms[0][0].std())
    tt_x.append(data.a.residualwavefront[0][:,349].mean())
    tt_x_err.append(data.a.residualwavefront[0][:,349].std())
    tt_y.append(data.a.residualwavefront[0][:,350].mean())
    tt_y_err.append(data.a.residualwavefront[0][:,350].std())
    defocus.append(data.a.residualwavefront[0][:,351].mean())
    defocus_err.append(data.a.residualwavefront[0][:,351].std())
    
print(time.time() - start)
# Out:
# 2686.530900001526

# %%
len(rms)
# Out:
# 956

# %%
plt.scatter(tt_x, df_rms.fwhm)
plt.xlim(-0.0005,0.0005)
plt.ylim(40,150)
plt.show()

# %%
plt.figure(figsize = (12,8))
plt.scatter(tt_x,df_rms.fwhm, s = 5)
plt.xlim(-0.0005,0.0005)
plt.ylim(40,150)
plt.xlabel('Tip Tilt (X) [V?]')
plt.ylabel('FWHM [milliarcsec]')
# Out:
# Text(0,0.5,'FWHM [milliarcsec]')

# %%
plt.figure(figsize = (12,8))
plt.scatter(rms,df_rms.fwhm, s = 5)
plt.xlim(0, 500)
plt.ylim(40,150)
plt.xlabel('RMS')
plt.ylabel('FWHM [milliarcsec]')
# Out:
# Text(0,0.5,'FWHM [milliarcsec]')

# %%
df_rms['residual_rms'] = rms
df_rms['rms_err'] = rms_err
df_rms['tt_x'] = tt_x
df_rms['tt_x_err'] = tt_x_err
df_rms['tt_y'] = tt_y
df_rms['tt_y_err'] = tt_y_err
df_rms['defocus'] = defocus
df_rms['defocus_err'] = defocus_err

# %%
t = Table.from_pandas(df_rms)

# %%
t.write('table_rms_TT.fits', format = 'fits')

# %%
t =
