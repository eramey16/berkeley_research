# %%
from astropy.io import fits
from astropy.table import Table
import numpy as np
import pandas as pd
import re
import glob
from astropy.time import Time

# %%
path = "/u/steverobinson/work/"
file = "table_rms_TT.fits"
data = Table.read(path+file)
data
# Out:
# <Table length=956>
#    file           strehl        ...       defocus          defocus_err
#  bytes10         float64        ...       float64            float64
# ---------- -------------------- ... ------------------- ------------------
# c0087.fits                0.121 ...   6.511286735534668 21.610389709472656
# c0088.fits                 0.15 ...    5.74362325668335 19.858470916748047
# c0089.fits  0.16899999999999998 ...     4.4451904296875 18.930374145507812
# c0090.fits                0.127 ...  2.8025076389312744  19.59459114074707
# c0091.fits                0.138 ...  2.8201119899749756 18.039155960083008
# c0092.fits                0.124 ...    4.45789909362793 19.123594284057617
# c0093.fits                0.106 ...    4.24393892288208 18.769269943237305
# c0094.fits                0.081 ... -12.366363525390625  40.14057159423828
# c0097.fits 0.054000000000000006 ...   8.606817245483398   19.2924747467041
# ...

# %%
data.to_numpy()
tf = ["0507" in x for x in data['file']]
tf = np.array(tf)
idxs = np.where(tf==True)
idxs
# Out:
# (array([], dtype=int64),)

# %%
tel_all = pd.read_csv(path+"telemetry_mjds", sep=",")
tel_all
# Out:
#       Unnamed: 0                                               file  \
# 0              0  /u/steverobinson/data/keck_telemetry/20170718/...
# 1              1  /u/steverobinson/data/keck_telemetry/20170718/...
# 2              2  /u/steverobinson/data/keck_telemetry/20170718/...
# 3              3  /u/steverobinson/data/keck_telemetry/20170718/...
# 4              4  /u/steverobinson/data/keck_telemetry/20170718/...
# ...          ...                                                ...
# 5597        5597  /u/steverobinson/data/keck_telemetry/20170826/...
# 5598        5598  /u/steverobinson/data/keck_telemetry/20170826/...
# 5599        5599  /u/steverobinson/data/keck_telemetry/20170826/...
# 5600        5600  /u/steverobinson/data/keck_telemetry/20170826/...
# 5601        5601  /u/steverobinson/data/keck_telemetry/20170826/...
#
#       telemetry_mjd
# 0       57952.39387
# 1       57952.39428
# 2       57952.39822
# 3       57952.39867
# 4       57952.39926
# ...             ...
# ...

# %%
t = Time(57952.39387, format='mjd')
tel_all = tel_all.dropna()
times = Time(tel_all['telemetry_mjd'].values, format='mjd')
times = times.datetime
# Out:
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 7 18 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# 5 4 2017
# ...

# %%
for name in glob.glob(path+"*"):
    print(name)
# Out:
# /u/steverobinson/work/keckao
# /u/steverobinson/work/DataTableSetup.txt
# /u/steverobinson/work/Research
# /u/steverobinson/work/Weather_Data_Extraction.ipynb
# /u/steverobinson/work/rsync.txt
# /u/steverobinson/work/lgsao
# /u/steverobinson/work/LGS_Metadata_Analysis2.ipynb
# /u/steverobinson/work/maos
# /u/steverobinson/work/programming
# /u/steverobinson/work/__pycache__
# /u/steverobinson/work/Untitled.ipynb
# /u/steverobinson/work/get_telemetry.py
# /u/steverobinson/work/telemetry_mjds
# /u/steverobinson/work/LGS_Metadata_Analysis.ipynb
# /u/steverobinson/work/Telemetry.ipynb
# /u/steverobinson/work/Untitled1.ipynb
# /u/steverobinson/work/add_rms.py
# /u/steverobinson/work/table_with_rms.fits
# /u/steverobinson/work/tele_table.fits
# /u/steverobinson/work/Telemetry2.ipynb
# /u/steverobinson/work/table_rms_TT.fits
# /u/steverobinson/work/Keck_Telemetry.ipynb
